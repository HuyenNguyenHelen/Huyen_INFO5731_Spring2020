# %% [markdown]
# <a href="https://colab.research.google.com/github/HuyenNguyenHelen/Huyen_INFO5731_Spring2020/blob/master/my_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CASE STUDY: WORD FREQUENCY ANALYSIS

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-74916ade-8470-425f-a62a-c45b0d04379f" name="files[]" multiple disabled />
#      <output id="result-74916ade-8470-425f-a62a-c45b0d04379f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Whiz_Bang.txt to Whiz_Bang.txt

# %%
import string
fin=open("Whiz_Bang.txt")
my_list=[]
for w in fin:
  word=w.split(string.punctuation + string.whitespace)
for w in word: 
  if w.isalpha():
    my_list.append(w)
  return my_list
# Out:
#   File "<ipython-input-43-5277eb9f4f7d>", line 9
#     return my_list
#     ^
# SyntaxError: 'return' outside function

# %%
# processing a file by eliminate all whitespace, puntuation..., and lowercase
import string
def processing_file(text):
  mlist=[]
  fin=open(text)
  for line in fin:
    processing_line(line, mlist)
  sorted(mlist)
  return mlist


def processing_line(line,mlist):
  line=line.replace("-"," ")
  line=line.split()

  for word in line:
    word=word.strip(string.punctuation + string.whitespace)
    word=word.lower()
    mlist.append(word)

processing_file("Whiz_Bang.txt")
# Out:
# ['\ufeffthe',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'captain',
#  "billy's",
#  'whiz',
#  'bang',
#  'vol',
#  '2',
#  'no',
#  '23',
#  'august',
#  '1921',
#  'by',
#  'various',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'united',
#  'states',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  'you',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  're',
#  'use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  'if',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'united',
#  'states',
#  "you'll",
#  'have',
#  'to',
#  'check',
#  'the',
# ...

# %%
# processing a file by eliminate all whitespace, puntuation..., and lowercase
# count the number of word in file, and calculate diversity of the text  
import string
from __future__ import division
def processing_file(text):
  mlist=[]
  fin=open(text)
  for line in fin:
    processing_line(line, mlist)
  sorted(mlist)
  return mlist


def processing_line(line,mlist):
  line=line.replace("-"," ")
  line=line.split()

  for word in line:
    word=word.strip(string.punctuation + string.whitespace)
    word=word.lower()
    mlist.append(word)

processing_file("Whiz_Bang.txt")
count=len([w for w in processing_file("Whiz_Bang.txt")]) # count the total words in text
diversity= len(set(w for w in processing_file("Whiz_Bang.txt")))
print( count/diversity)
# Out:
# 4.117094861660079

# %%
# processing a file by eliminate all whitespace, puntuation..., and lowercase
# count the number of word in file, and calculate diversity of the text 
# count/report the frequency of word in text with hist and dict 
import string
from __future__ import division
def processing_file(text):
  hist={}
  fin=open(text)
  for line in fin:
    processing_line(line, hist)
  return hist

def processing_line(line,hist):
  line=line.replace("-"," ")
  line=line.split()

  for word in line:
    word=word.strip(string.punctuation + string.whitespace)
    word=word.lower()
    hist[word]=hist.get(word,0)+1
    return hist
def total_word(hist):
   sum(hist.value())
def different_word (hist):
  return len(hist)
def __main__(hist):
  print("The total number of word is" ,total_word)
  print ("The number of different word is", different_word)
("Whiz_Bang.txt")
# Out:
# The total number of word is <function total_word at 0x7f0b17ed5e18>
# The number of different word is <function different_word at 0x7f0b17f591e0>

# %%
line="ajdjdldl kckllc"
line.split("d")
# Out:
# ['aj', 'j', 'l', 'l kckllc']

# %%
a="abdhdi"
tuple(a)
# Out:
# ('a', 'b', 'd', 'h', 'd', 'i')
