# %% [markdown]
# <a href="https://colab.research.google.com/github/HuyenNguyenHelen/Huyen_INFO5731_Spring2020/blob/master/Copie_de_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> book
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
# ...

# %%
from nltk.book import *
text5.concordance("friend")
text5.concordance("perfect")
text1.concordance("monstrous")
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# Displaying 8 of 8 matches:
# ur nose .. But you ca n't pick your friend s nose . JOIN . ACTION sticks his f
# e U85 Your name looks male to me My friend had a horse name U86 lol donno why
# t's sucks JOIN I caught Mono from a friend s drink lol . ACTION . Liam 's . 13
# ut not really besides U45 who is my friend PART hes cool too Anyone wanna Cybe
#  broke come on now guys LOL you can friend him , lex , and lois ! buy U54 a pu
# ...

# %%
text1.similar("monstrous")
text2.similar("monstrous")
text3.similar("monstrous")
text1.similar("monstrous")
text2.similar("monstrous")
text4.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly
# No matches
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly
# No matches

# %%
text2.common_contexts(["monstrous", "very"])
text1.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad
# No common contexts were found

# %%
text5.concordance("perfect")
text9.concordance("perfect")
text1.concordance("perfect")
text4.concordance("perfect")
# Out:
# Displaying 2 of 2 matches:
# er how to cook .. turn her into the perfect lil housewife for ya . any females
# Hello Richard . your cat walks in a perfect line , im impressed ! Sup Joe . JOI
# Displaying 10 of 10 matches:
# e place was not only pleasant , but perfect , if once he could regard it not as
# urst of blazing light , one peal of perfect thunder , than the mere common bodi
# unk , I am mad ," replied Syme with perfect calm ; " but I trust I can behave l
#  suggesting fine shades and picking perfect words . He thought that with care h
# ol , but our best symbol . It is as perfect a symbol of us as is incense of the
# lked out of the room with an air of perfect nonchalance . Yet the astonished Sy
#  topmost point , and to pick out in perfect silver the great orb and the cross
# ur of admiration . The curse of the perfect artist had fallen upon me . I had b
# ers and short hair , made me look a perfect little devil . As I say , it was si
# ...

# %%
text1.similar("perfect")
text2.similar("perfect")
text3.similar("perfect")
text4.similar("perfect")
text5.similar("perfect")
text6.similar("perfect")
text7.similar("perfect")
text8.similar("perfect")
# Out:
# general before such margaret possible happy same match
# in said saw went art go return live turned came wroth dwelt died lo
# calneh goest camest sat early sojourned
# secure have me that it be all execute you free adopt them add us
# produce establish provide see certain make
# better
# No matches
# No matches

# %%
text4.common_contexts(["perfect", "more"])
# Out:
# be_and

# %%
import numpy
import matplotlib

# %%
text5.generate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-6fb05464c357> in <module>()
# ----> 1 text5.generate()
#
# TypeError: generate() missing 1 required positional argument: 'words'

# %%
len(text3)
set(text3)
# Out:
# {'avenged',
#  'drinketh',
#  'threshingfloor',
#  'goats',
#  'Dumah',
#  'unit',
#  'Rameses',
#  'windows',
#  'Ard',
#  'two',
#  'Should',
#  'Unto',
#  'fill',
#  'h',
#  'prison',
#  'service',
#  'hearts',
#  'foolishly',
#  'activity',
#  'Baalhanan',
#  'After',
#  'besides',
#  'dead',
#  'Eldaah',
#  'dim',
#  'gifts',
#  'even',
#  'double',
#  'turned',
#  'rested',
#  'blessi',
#  'To',
#  'selfwill',
#  'Said',
#  'seasons',
#  'Angel',
#  'Ararat',
#  'fire',
#  'handle',
#  'him',
#  'Phut',
#  'business',
#  'bowed',
#  'Gihon',
#  'Methuselah',
#  'smell',
#  'abide',
#  'grove',
#  'appointed',
#  'bowing',
#  'should',
#  'under',
#  'He',
#  'tar',
#  'refrain',
#  'confound',
#  'that',
#  'say',
#  'Cheran',
#  'slayeth',
#  'naked',
#  'such',
#  'goest',
#  'mightier',
#  'fellow',
#  'loins',
#  'Come',
#  'hunter',
#  'upright',
#  'waxed',
#  'indeed',
#  'straitly',
#  'Lot',
#  'why',
#  'white',
#  'Happy',
#  'audience',
#  'oversig',
# ...

# %%
#my turn
from __future__ import division 
text5.count("lol")/len(text5) *100
# Out:
# 1.5640968673628082

# %%
# create my own functions: lexical_diversity and occurancy 
from nltk.book import *
from __future__ import division 
def lexical_diversity(text):
  print(len(text)/len(set(text)))
def occurancy (text, word):
  print((text.count(word)/len(text))*100)

occurancy(text1, "monstrous")
lexical_diversity (text1)
lexical_diversity (text2)
lexical_diversity (text3)
lexical_diversity (text4)
lexical_diversity (text5)
lexical_diversity (text6)
lexical_diversity (text7)
lexical_diversity (text8)
lexical_diversity (text9)
# Out:
# 0.003834076505162584
# 13.502044830977896
# 20.719449729255086
# 16.050197203298673
# 15.111167154241905
# 7.420046158918563
# 7.833333333333333
# 8.113797549967762
# 4.39259927797834
# 10.167915381225209

# %%
print(sent1)
print(sorted(sent1))
len(sent3)
# Out:
# ['Call', 'me', 'Ishmael', '.']
# ['.', 'Call', 'Ishmael', 'me']
# 11

# %% [markdown]
# FINE-GRAINED SELECTION OF WORDS P.19

# %%
# Conveniently! instead create a list separately and run for loop, now I just run a for loop inside a created list. Easy!
v=set(text1)
long_words=[w for w in v if len(w)>15]
print(long_words)
sorted(long_words)
# Out:
# ['responsibilities', 'Physiognomically', 'preternaturalness', 'physiognomically', 'comprehensiveness', 'indispensableness', 'hermaphroditical', 'undiscriminating', 'circumnavigating', 'uncompromisedness', 'simultaneousness', 'apprehensiveness', 'characteristically', 'uninterpenetratingly', 'circumnavigation', 'subterraneousness', 'circumnavigations', 'CIRCUMNAVIGATION', 'supernaturalness', 'cannibalistically', 'indiscriminately', 'uncomfortableness', 'irresistibleness', 'superstitiousness']
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
# ...

# %%
# I defined a function for above action, but why it cannot return a sorted list?

def my_list (text):
  above_fifteen=[]
  for w in set(text):
    if len(w)>15:
      above_fifteen.append(w)
  return above_fifteen
  sorted(above_fifteen)
      
my_list(text1)
# Out:
# ['responsibilities',
#  'Physiognomically',
#  'preternaturalness',
#  'physiognomically',
#  'comprehensiveness',
#  'indispensableness',
#  'hermaphroditical',
#  'undiscriminating',
#  'circumnavigating',
#  'uncompromisedness',
#  'simultaneousness',
#  'apprehensiveness',
#  'characteristically',
#  'uninterpenetratingly',
#  'circumnavigation',
#  'subterraneousness',
#  'circumnavigations',
#  'CIRCUMNAVIGATION',
#  'supernaturalness',
#  'cannibalistically',
#  'indiscriminately',
#  'uncomfortableness',
#  'irresistibleness',
#  'superstitiousness']
